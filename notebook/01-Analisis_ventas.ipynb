# %% [markdown]
# ## Importación de Librerías

# %%
import pandas as pd

# %% [markdown]
# ## Carga de datos

# %%
df = pd.read_csv(
    r"C:/Users/smp/OneDrive - Grupo JJChicolino/THE POWER/PROYECTOFINALEDA/data/raw/ventas2024.csv",
    sep=";",
    encoding="latin1",     # prueba esta primera
    on_bad_lines="skip",
    decimal=",", 
    parse_dates=["Fecha"]  # intenta convertir 'Fecha' a datetime
)
# Out:
# C:\Users\smp\AppData\Local\Temp\ipykernel_6108\2092747999.py:1: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv(

# %%
df.sample(50)
# Out:
#        codcompany                            IdCustomer      Fecha  \
# 20604          21                            021-004296 2024-10-23
# 23963          21                            021-006091 2024-02-14
# 17163          21                            021-006195 2024-11-18
# 30578           5  8ae370fb-2aa5-42fd-900b-d44a0b69a10c 2024-12-23
# 3044            1                            001-006780 2024-04-10
# 27913           5  5b016eb1-ce24-4d9b-b446-e8b66b6eff5f 2024-11-11
# 13488           5  0950cb7f-5072-4dc0-9557-a54eadbceaeb 2024-09-17
# 13769           5                            005-004525 2024-11-21
# 438             1                            001-000202 2024-01-16
# 4418            5                            005-001237 2024-08-12
# 13816           5                            005-001238 2024-12-31
# 10870           5                            005-001238 2024-02-29
# 3840            5  3c0237c1-2db3-4c1b-a8a0-eb56099eb18c 2024-07-29
# 12558           5                            005-001315 2024-08-14
# 21523          21                            021-006587 2024-09-16
# 14506           5                            005-004297 2024-06-06
# 11079           5                            005-004350 2024-06-13
# 27335          21  6d56775f-b8fc-432a-8e94-a5e7c3939222 2024-02-02
# 25960          21  9eb0d390-8eb6-4429-b805-2dfb9bc430ca 2024-09-30
# 29999          21                            021-006150 2024-04-02
# 6968            5  30e002d6-8ba2-41cd-ba17-37e084430bd7 2024-08-23
# 3943            1                            001-003451 2024-11-29
# 21043           1  3c3e2ee6-fe63-42ac-9ac6-2541ceba0cfa 2024-06-25
# 25235          21                            021-006150 2024-03-05
# 15908          21                            021-006883 2024-02-01
# 17825           5  ee6139cd-0b6c-49e5-a7e5-a77f072418e8 2024-12-23
# 29670           5                            005-002371 2024-12-23
# 28615          21                            021-006514 2024-12-27
# 28486           1                            001-003451 2024-05-31
# 1998            1  46a9ddf3-10e0-4513-a560-27539c3e4c91 2024-01-17
# 15671           5                            005-003318 2024-12-30
# 5454            5                            005-001240 2024-03-19
# 6239            5                            005-002036 2024-12-24
# 1030            1                            001-004486 2024-04-04
# 12384           5                            005-006942 2024-03-08
# 24602          21                            021-006195 2024-02-22
# 30268          21                            021-006195 2024-06-07
# 28240           5                            005-006021 2024-12-05
# 21551          21                            021-006883 2024-06-06
# 30777           5                            005-003147 2024-02-02
# 414             1  275acc43-55f6-4caf-98db-1c3b00f57e49 2024-03-01
# 23321          21                            021-006150 2024-11-14
# 27960           5  8a0b39da-a257-453f-8b32-8bd86ee28adb 2024-11-14
# 28827           5                            005-001240 2024-07-24
# 22479          21                            021-006150 2024-10-01
# 29381          21                            021-006150 2024-06-28
# 5593            5                            005-001238 2024-08-30
# 5456            5                            005-001240 2024-07-09
# 25175           1                            001-003451 2024-08-30
# 16775          21                            021-006587 2024-08-22
#
#                                   IDArticle  Quantity  SaleAmount  TypeLine  \
# 20604                     021-035a0700ampur     4.000     2204.00         0
# 23963                                021-lm     1.000        0.00         0
# 17163                           021-ysmo007     4.000        0.00         0
# 30578  b7f2ec87-8e2f-48b5-a86e-b18c47498918     1.000      165.00         0
# 3044                              001-22301    54.000      464.40         0
# 27913  61e5f526-e3bb-4a28-8d1a-d7f3076e9a26     8.392        0.00         0
# 13488                           005-ecb0109     1.000       20.40         0
# 13769                           005-ecb3216     1.000        6.00         0
# 438                          001-053am16/4c    40.000      150.00         0
# 4418                         005-020a5030ne    10.000     1120.00         0
# 13816                          005-ecb5301a     1.000        6.50         0
# 10870                           005-199s002    90.000        0.00         0
# 3840                       005-010a093650am     2.000       96.10         0
# 12558                           005-199s003     0.250        5.25         0
# 21523                                021-lm     1.000        0.00         0
# 14506                           005-ecb3005    20.000       83.00         0
# 11079                           005-199s002    70.000        0.00         0
# 27335  4d5d6dac-6c1f-4aeb-a44e-e693dd402f42     1.000      350.00         0
# 25960  6176de39-2bfb-470c-a056-69de3d775bde    23.000     8395.00         0
# 29999  a267b3e0-ceb1-46bd-a9de-886e7bd1a9b8    50.000      300.00         0
# 6968                            005-160ar12    16.000       21.26         0
# 3943                                 001-lm     1.000        0.00         0
# 21043  327ce516-fac9-4107-8a1e-e01f856da204   500.000       38.00         0
# 25235  1ebbff29-3ccf-4fa2-9851-4e6ce65bdd34     4.000      170.20         0
# 15908                            021-47ll01     3.000        0.00         0
# 17825                                005-lm     1.000        0.00         0
# 29670  9552ca6f-33e6-41b0-abc8-89ea04286ffd     2.000       53.30         0
# 28615  76adad15-4cc8-4c45-89a8-322a63d9f019     1.000      388.00         0
# 28486  68da5e92-16c2-4ca6-9580-ed86667dc0b0   205.750    18826.13         0
# 1998                              001-10303     1.000       54.00         0
# 15671                          005-grn88256     1.000      108.00         0
# 5454                         005-133d06jf01     0.711      607.91         0
# 6239                         005-137260175c     0.274       50.96         0
# 1030                            001-04110az  1000.000       72.00         0
# 12384                             005-32615     1.000        0.00         0
# 24602                           021-ysmo010     1.000      463.78         0
# 30268  a9addecf-5b21-4c1d-aec7-728dae3ed8f4    56.000       36.40         0
# 28240  611afa77-8800-4358-8f83-1f586884c594     4.000     3904.56         0
# 21551                                021-lm     1.000        0.00         0
# 30777  b7c54fc3-469d-423b-ab20-fd3c9f806b0b     0.600      573.60         0
# 414                           001-051s16/3c    10.620       33.45         0
# 23321                                021-lm     1.000        0.00         0
# 27960  5d142c98-5940-42b3-a86f-2212c2e053e9     2.000      306.00         0
# 28827  78c9133a-ec89-48d0-aca5-b65b951bbe67    12.000      516.00         0
# 22479                                021-lm     1.000        0.00         0
# 29381  915e1ba0-a1e7-4875-9cff-5cc30e901d80    26.000     1666.86         0
# 5593                        005-133g02jmd08     0.312      391.87         0
# 5456                         005-133d06jf01     0.784      670.32         0
# 25175  458834c2-a96b-4022-91ed-88e7514190e9    40.000     3501.20         0
# 16775                            021-ys8810     1.000      165.00         0
#
#         CostAmount  AmountDiscount                       IDPaymentMethod  ...  \
# 20604    854.94000               0                                 021-3  ...
# 23963      0.00000               0                                021-21  ...
# 17163      0.00400               0                                021-33  ...
# 30578     86.65000               0                               005-6-1  ...
# 3044     320.63634               0                                001-17  ...
# 27913    799.92544               0                              005-17-1  ...
# 13488     14.27951               0                              005-17-1  ...
# 13769      2.94417               0                              005-17-1  ...
# 438       88.53760               0                                 001-6  ...
# 4418     810.40000               0                              005-82-1  ...
# 13816      3.92241               0                              005-29-1  ...
# 10870     19.80000               0                              005-29-1  ...
# 3840      58.22000               0                              005-33-1  ...
# 12558      3.25000               0                               005-6-1  ...
# 21523      0.00000               0                                021-38  ...
# 14506     44.62800               0                              005-67-1  ...
# 11079     15.40000               0                              005-99-1  ...
# 27335    413.45000               0                                 021-4  ...
# 25960   4417.84000               0                                021-99  ...
# 29999    669.00000               0                                021-91  ...
# 6968      16.07344               0                              005-81-1  ...
# 3943       0.00000               0                                 001-4  ...
# 21043     25.80000               0  645631ef-9d10-4164-a2c6-42f7ac77734b  ...
# 25235    244.84000               0                                021-91  ...
# 15908      7.30425               0                                021-38  ...
# 17825      0.00000               0  8cf39cbb-bd3e-4186-92ad-94d138df1ba4  ...
# 29670     33.56000               0                               005-6-1  ...
# 28615    266.91000               0                                 021-3  ...
# 28486  18826.12500               0  95839b62-ccc4-4a70-a894-012c7d43a5bb  ...
# 1998      37.16609               0                                 001-8  ...
# 15671     63.65954               0                               005-3-1  ...
# 5454     396.75933               0                              005-82-1  ...
# 6239      23.99144               0                              005-16-1  ...
# 1030      52.04000               0                                 001-6  ...
# 12384      3.00000               0                               005-1-1  ...
# 24602     77.20000               0                                021-37  ...
# 30268     26.48576               0                                021-37  ...
# 28240   2365.28000               0                             005-100-1  ...
# 21551      0.00000               0                                021-38  ...
# 30777    358.62000               0                              005-81-1  ...
# 414       21.77100               0                                 001-8  ...
# 23321      0.00000               0                                021-91  ...
# 27960    146.28000               0                              005-33-1  ...
# 28827    342.92508               0                              005-82-1  ...
# 22479      0.00000               0                                021-91  ...
# 29381   1788.80000               0                                021-91  ...
# 5593     283.15872               0                              005-29-1  ...
# 5456     416.15504               0                              005-82-1  ...
# 25175   3501.20000               0  95839b62-ccc4-4a70-a894-012c7d43a5bb  ...
# 16775    145.17000               0                                021-38  ...
#
#       CODCUSTOMER                                            Cliente  \
# 20604        4296                    TRILLO ANCLAS Y CADENAS, S.L.U.
# 23963        6091       ALMARIN EQUIPOS Y SERVICIOS PORTUARIOS, S.L.
# 17163        6195          DESARROLLO DISEÑO & STYLING, S.L.U. (DDS)
# 30578        7237                    MEJILLONERAS DEL BARBANZA, S.L.
# 3044         6780                                    CASGROMEX, S.L.
# 27913        7325                                OYSTER OASIS S.R.L.
# 13488        7396                          AURELIO SILVA ABALO, S.L.
# 13769        4525                FALCAMAR-COMERCIO DE MARISCOS, LDA.
# 438           202                              PROL LLORENS, EUGENIO
# 4418         1237                             MARISCOS CAMPELO, S.A.
# 13816        1238             JOSE MARIA DAPORTA LEIRO E HIJOS, S.L.
# 10870        1238             JOSE MARIA DAPORTA LEIRO E HIJOS, S.L.
# 3840         8165  TECNOLOGIAS Y SERVICIOS AGRARIOS S.A  S.M.E. M...
# 12558        1315                              MARISCOS JOYFRA, S.L.
# 21523        6587                                       ROTOGAL GMBH
# 14506        4297                                MARISC CATALA, S.L.
# 11079        4350                                MARISCOS INES, S.L.
# 27335        8581  ORGANIZACION DE PRODUCTORES PESQUEROS ARTESANA...
# 25960        8484              GRUPO ACUICOLA SANTA FE, S.A. DE C.V.
# 29999        6150                                FORMATO VERDE, S.L.
# 6968         7966  HEREDEROS DE ANGEL MARIÑO HERMO, C.B. (ANGEL MAR)
# 3943         3451                ENVASES DE GALICIA, S.A.U. (EGALSA)
# 21043        7561                                   RIO SANLEX, S.L.
# 25235        6150                                FORMATO VERDE, S.L.
# 15908        6883                      DANSK TRANSPORT EMBALLAGE A/S
# 17825        7750                           ANGULAS AGUINAGA, S.A.U.
# 29670        2371         CULTIUS MARINS DEL DELTA DE L'EBRE, S.A.U.
# 28615        6514                       PEREZ QUEIRUGA E HIJOS, S.L.
# 28486        3451                ENVASES DE GALICIA, S.A.U. (EGALSA)
# 1998         7873                        CASTRO NINE, FRANCISCO JOSE
# 15671        3318          RAMIRO MARTINEZ, S.L. (EMBUTIDOS MONTIÑO)
# 5454         1240                               JOAQUIN FARIÑA, S.L.
# 6239         2036                   ATXEGA PESCADOS Y MARISCOS, S.A.
# 1030         4486                               RUA BOUBETA, ORLANDO
# 12384        6942                       JOSE FERNANDEZ PIÑEIRO, S.L.
# 24602        6195          DESARROLLO DISEÑO & STYLING, S.L.U. (DDS)
# 30268        6195          DESARROLLO DISEÑO & STYLING, S.L.U. (DDS)
# 28240        6021                            MARISCOS WILDOMAR, S.L.
# 21551        6883                      DANSK TRANSPORT EMBALLAGE A/S
# 30777        3147                                   MARESMAR, S.L.U.
# 414          7403                        ORDOÑEZ COMOJO, JOSE JAVIER
# 23321        6150                                FORMATO VERDE, S.L.
# 27960        7781                    VERDE QUE TE QUIERO VERDE, S.L.
# 28827        1240                               JOAQUIN FARIÑA, S.L.
# 22479        6150                                FORMATO VERDE, S.L.
# 29381        6150                                FORMATO VERDE, S.L.
# 5593         1238             JOSE MARIA DAPORTA LEIRO E HIJOS, S.L.
# 5456         1240                               JOAQUIN FARIÑA, S.L.
# 25175        3451                ENVASES DE GALICIA, S.A.U. (EGALSA)
# 16775        6587                                       ROTOGAL GMBH
#
#       CODVOUCHERTYPE               tipoasiento CODPRODUCTLINE  \
# 20604             10         VENTAS NACIONALES          MFR04
# 23963             10         VENTAS NACIONALES          MFC02
# 17163             10         VENTAS NACIONALES          MFR05
# 30578             10         VENTAS NACIONALES            MF6
# 3044              10         VENTAS NACIONALES            MF5
# 27913             11  VENTAS INTRACOMUNITARIAS            MF6
# 13488             10         VENTAS NACIONALES            MF8
# 13769             11  VENTAS INTRACOMUNITARIAS            MF8
# 438               10         VENTAS NACIONALES            MF5
# 4418              10         VENTAS NACIONALES            MF6
# 13816             10         VENTAS NACIONALES            MF8
# 10870             10         VENTAS NACIONALES           MF12
# 3840              10         VENTAS NACIONALES            MF6
# 12558             10         VENTAS NACIONALES           MF12
# 21523             11  VENTAS INTRACOMUNITARIAS          MFC02
# 14506             10         VENTAS NACIONALES            MF8
# 11079             10         VENTAS NACIONALES           MF12
# 27335             10         VENTAS NACIONALES          MFR03
# 25960             12      VENTAS EXPORTACIONES          MFR03
# 29999             10         VENTAS NACIONALES          MFR01
# 6968              10         VENTAS NACIONALES            MF6
# 3943              10         VENTAS NACIONALES           MF12
# 21043             10         VENTAS NACIONALES            MF5
# 25235             10         VENTAS NACIONALES          MFR01
# 15908             11  VENTAS INTRACOMUNITARIAS          MFC01
# 17825             10         VENTAS NACIONALES          MFC02
# 29670             10         VENTAS NACIONALES            MF8
# 28615             10         VENTAS NACIONALES          MFR02
# 28486             10         VENTAS NACIONALES            MF6
# 1998              10         VENTAS NACIONALES            MF5
# 15671             10         VENTAS NACIONALES            MF8
# 5454              10         VENTAS NACIONALES            MF6
# 6239              10         VENTAS NACIONALES            MF6
# 1030              10         VENTAS NACIONALES            MF5
# 12384             10         VENTAS NACIONALES            MF1
# 24602             10         VENTAS NACIONALES          MFR06
# 30268             10         VENTAS NACIONALES          MFC01
# 28240             10         VENTAS NACIONALES            MF6
# 21551             11  VENTAS INTRACOMUNITARIAS          MFC02
# 30777             10         VENTAS NACIONALES            MF6
# 414               10         VENTAS NACIONALES            MF5
# 23321             10         VENTAS NACIONALES          MFC02
# 27960             12      VENTAS EXPORTACIONES            MF6
# 28827             10         VENTAS NACIONALES            MF9
# 22479             10         VENTAS NACIONALES          MFC02
# 29381             10         VENTAS NACIONALES          MFR01
# 5593              10         VENTAS NACIONALES            MF6
# 5456              10         VENTAS NACIONALES            MF6
# 25175             10         VENTAS NACIONALES            MF6
# 16775             11  VENTAS INTRACOMUNITARIAS          MFR05
#
#                                macrofamilia CODPRODUCTFAMILY  \
# 20604                                Marine            FR04A
# 23963                                Varios            FC02C
# 17163                        Varios Rotogal            FR05B
# 30578                   Envases y Embalajes              F33
# 3044                        Efectos Navales              F37
# 27913                   Envases y Embalajes              F13
# 13488                      Maquinaria y SAT              F35
# 13769                      Maquinaria y SAT              F35
# 438                         Efectos Navales               F1
# 4418                    Envases y Embalajes              F33
# 13816                      Maquinaria y SAT              F35
# 10870                                Varios              F36
# 3840                    Envases y Embalajes              F33
# 12558                                Varios              F36
# 21523                                Varios            FC02C
# 14506                      Maquinaria y SAT              F35
# 11079                                Varios              F36
# 27335                           Manutención            FR03A
# 25960                           Manutención            FR03A
# 29999                        Custom Molding            FR01A
# 6968                    Envases y Embalajes              F15
# 3943                                 Varios              F24
# 21043                       Efectos Navales              F37
# 25235                        Custom Molding            FR01A
# 15908                       Consumo Interno            FC01C
# 17825                                Varios            FC02C
# 29670                      Maquinaria y SAT              F35
# 28615                                 Vruma            FR02A
# 28486                   Envases y Embalajes              F33
# 1998                        Efectos Navales              F37
# 15671                      Maquinaria y SAT              F35
# 5454                    Envases y Embalajes              F13
# 6239                    Envases y Embalajes              F13
# 1030                        Efectos Navales              F37
# 12384                       Consumo Interno               F8
# 24602        Calderería Plastica y Metálica            FR06B
# 30268                       Consumo Interno            FC01C
# 28240                   Envases y Embalajes              F13
# 21551                                Varios            FC02C
# 30777                   Envases y Embalajes              F13
# 414                         Efectos Navales               F1
# 23321                                Varios            FC02C
# 27960                   Envases y Embalajes              F34
# 28827  Reciclaje y valorización de Residuos               F4
# 22479                                Varios            FC02C
# 29381                        Custom Molding            FR01A
# 5593                    Envases y Embalajes              F13
# 5456                    Envases y Embalajes              F13
# 25175                   Envases y Embalajes              F33
# 16775                        Varios Rotogal            FR05B
#
#                              familia CODPRODUCTSUBFAMILY  \
# 20604            Acuicultura y pesca                 AP3
# 23963               Material Diverso                  AS
# 17163              Servicios Rotogal                 SMO
# 30578       Sacos y Mallas Extruidas                 020
# 3044              Suministros Varios                 223
# 27913                 Envases Madera                 137
# 13488                Consumibles SAT                 ECB
# 13769                Consumibles SAT                 ECB
# 438                 Cabos y Estachas                 053
# 4418        Sacos y Mallas Extruidas                 020
# 13816                Consumibles SAT                 ECB
# 10870               Servicios Varios                199S
# 3840        Sacos y Mallas Extruidas                 010
# 12558               Servicios Varios                199S
# 21523               Material Diverso                  AS
# 14506                Consumibles SAT                 ECB
# 11079               Servicios Varios                199S
# 27335                           Bins                 010
# 25960                           Bins                 010
# 29999                  Formato Verde                 CA3
# 6968       Envases Plasticos Rigidos                 160
# 3943                Material Diverso                  YM
# 21043             Suministros Varios                 041
# 25235                  Formato Verde                 CA4
# 15908       Componentes y Accesorios                  51
# 17825               Material Diverso                  AS
# 29670                Consumibles SAT                  LV
# 28615                  Embarcaciones                 V02
# 28486       Sacos y Mallas Extruidas                 020
# 1998              Suministros Varios                 103
# 15671                Consumibles SAT                 GRN
# 5454                  Envases Madera                 133
# 6239                  Envases Madera                 137
# 1030              Suministros Varios                 041
# 12384  Consumo Interno y componentes                  32
# 24602            Calderería Metálica                 CM3
# 30268       Componentes y Accesorios                  65
# 28240                 Envases Madera                 132
# 21551               Material Diverso                  AS
# 30777                 Envases Madera                 133
# 414                 Cabos y Estachas                 051
# 23321               Material Diverso                  AS
# 27960         Sacos y Mallas Tejidas                 071
# 28827            Chatarra y Residuos                 197
# 22479               Material Diverso                  AS
# 29381                  Formato Verde                 CA2
# 5593                  Envases Madera                 133
# 5456                  Envases Madera                 133
# 25175       Sacos y Mallas Extruidas                 009
# 16775              Servicios Rotogal                 SVP
#
#                                  subfamilia
# 20604                     BOYAS ACUICULTURA
# 23963        ARTICULOS SIN CONTROL DE STOCK
# 17163                          MANO DE OBRA
# 30578                                 SACOS
# 3044   PROD. RODEAR RED TUBULAR (NO PROPIO)
# 27913                          TAPAS CAIXAS
# 13488                 REPUESTOS ECONOMY BAG
# 13769                 REPUESTOS ECONOMY BAG
# 438                    CABO POLIESTER (PES)
# 4418                                  SACOS
# 13816                 REPUESTOS ECONOMY BAG
# 10870                  SERVICIOS VARIOS SAT
# 3840                         MALLA MOLUSCOS
# 12558                  SERVICIOS VARIOS SAT
# 21523        ARTICULOS SIN CONTROL DE STOCK
# 14506                 REPUESTOS ECONOMY BAG
# 11079                  SERVICIOS VARIOS SAT
# 27335                       BIN ISOTERMICO
# 25960                       BIN ISOTERMICO
# 29999                                 BOCAS
# 6968                     CAJAS POLIESTIRENO
# 3943                       MATERIAL DIVERSO
# 21043              MATERIAL MEJILLON VARIOS
# 25235                                 TAPAS
# 15908                      CONSUMIBLES BINS
# 17825        ARTICULOS SIN CONTROL DE STOCK
# 29670                    REPUESTOS LAVADORA
# 28615                                 PESCA
# 28486                                 SACOS
# 1998        MATERIAL EFECTOS NAVALES VARIOS
# 15671        REPUESTOS GRAP. NEUMATICA AN-1
# 5454                 CAIXAS RECTAS CLASICAS
# 6239                           TAPAS CAIXAS
# 1030               MATERIAL MEJILLON VARIOS
# 12384     CAJAS-MATERIA PRIMA - COMPONENTES
# 24602         SERVICIOS CALDERERÍA METÁLICA
# 30268                  CONSUMIBLES EMBALAJE
# 28240        BARCAS BISELADAS PLASTIFICADAS
# 21551        ARTICULOS SIN CONTROL DE STOCK
# 30777                CAIXAS RECTAS CLASICAS
# 414                        CABO POLIESTEEL
# 23321        ARTICULOS SIN CONTROL DE STOCK
# 27960                             NATURLINE
# 28827                       RESIDUOS MADERA
# 22479        ARTICULOS SIN CONTROL DE STOCK
# 29381                            CINTURONES
# 5593                 CAIXAS RECTAS CLASICAS
# 5456                 CAIXAS RECTAS CLASICAS
# 25175                           MALLA PLANA
# 16775                                PORTES
#
# [50 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33877 entries, 0 to 33876
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   codcompany           33877 non-null  int64
#  1   IdCustomer           33877 non-null  object
#  2   Fecha                33877 non-null  datetime64[ns]
#  3   IDArticle            33877 non-null  object
#  4   Quantity             33877 non-null  float64
#  5   SaleAmount           33877 non-null  float64
#  6   TypeLine             33877 non-null  int64
#  7   CostAmount           33877 non-null  float64
#  8   AmountDiscount       33877 non-null  int64
#  9   IDPaymentMethod      33877 non-null  object
#  10  Documento            33877 non-null  object
#  11  CODCUSTOMER          33877 non-null  int64
#  12  Cliente              33877 non-null  object
#  13  CODVOUCHERTYPE       33877 non-null  int64
#  14  tipoasiento          33877 non-null  object
#  15  CODPRODUCTLINE       33877 non-null  object
#  16  macrofamilia         33877 non-null  object
#  17  CODPRODUCTFAMILY     33877 non-null  object
#  18  familia              33877 non-null  object
#  19  CODPRODUCTSUBFAMILY  33877 non-null  object
#  20  subfamilia           33877 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(5), object(12)
# memory usage: 5.4+ MB

# %% [markdown]
# ## Columnas del dataset
#
# -ï»¿codcompany: Código identificador de la empresa
#
# -IdCustomer: Identificador del cliente
#
# -Fecha: Fecha de la transacción o venta
#
# -IDArticle: Código identificador del artículo o producto
#
# -Quantity: Cantidad vendida
#
# -SaleAmount: Importe de la venta
#
# -TypeLine: Tipo de línea o categoría de producto
#
# -CostAmount: Coste asociado a la venta
#
# -AmountDiscount: Monto del descuento aplicado
#
# -IDPaymentMethod: Identificador del método de pago
#
# -Documento: Número o código del documento o factura
#
# -CODCUSTOMER: Código numérico identificador del cliente
#
# -Cliente: Nombre del cliente
#
# -CODVOUCHERTYPE: Código del tipo de comprobante o voucher
#
# -tipoasiento: Tipo de asiento contable o asiento de la transacción
#
# -CODPRODUCTLINE: Código de la línea de producto
#
# -macrofamilia: Nombre de la macrofamilia
#
# -CODPRODUCTFAMILY: Código de la familia del producto
#
# -familia: Nombre de la familia del producto
#
# -CODPRODUCTSUBFAMILY: Código de la subfamilia del producto
#
# -subfamilia: Nombre de la subfamilia del producto

# %% [markdown]
# ## Columnas a corregir:
#
# -ï»¿codcompany renombrar a codcompany
#
# -AmountDiscount: es int64, está bien si solo hay descuentos enteros, pero si pueden ser decimales, mejor float.
#
# -Normalizar los nombres de las columnas

# %%
df.rename(columns={'ï»¿codcompany': 'codcompany'}, inplace=True)

# %%
df['AmountDiscount'] = df['AmountDiscount'].astype(float)

# %%
df.columns = (
    df.columns
    .str.strip()  # quita espacios
    .str.lower()  # todo minúsculas
    .str.replace('ï»¿', '', regex=False)  # elimina el BOM raro
    .str.replace('[^0-9a-zA-Z]+', '_', regex=True)  # sustituye símbolos por "_"
)

# %%
print(df.columns.tolist())
# Out:
# ['codcompany', 'idcustomer', 'fecha', 'idarticle', 'quantity', 'saleamount', 'typeline', 'costamount', 'amountdiscount', 'idpaymentmethod', 'documento', 'codcustomer', 'cliente', 'codvouchertype', 'tipoasiento', 'codproductline', 'macrofamilia', 'codproductfamily', 'familia', 'codproductsubfamily', 'subfamilia']

# %% [markdown]
# ## Revisar nulos

# %%
df.isnull().sum()
# Out:
# codcompany             0
# idcustomer             0
# fecha                  0
# idarticle              0
# quantity               0
# saleamount             0
# typeline               0
# costamount             0
# amountdiscount         0
# idpaymentmethod        0
# documento              0
# codcustomer            0
# cliente                0
# codvouchertype         0
# tipoasiento            0
# codproductline         0
# macrofamilia           0
# codproductfamily       0
# familia                0
# codproductsubfamily    0
# subfamilia             0
# dtype: int64

# %% [markdown]
# ## Revisar duplicados

# %%
df.duplicated().sum()
# Out:
# np.int64(3887)

# %% [markdown]
# ## Variables numéricas

# %%
columnas_num=df.select_dtypes(include=['number']).columns.tolist()

# %%
columnas_num
# Out:
# ['codcompany',
#  'quantity',
#  'saleamount',
#  'typeline',
#  'costamount',
#  'amountdiscount',
#  'codcustomer',
#  'codvouchertype']

# %%
df.describe(include='number').T.round(2)
# Out:
#                   count     mean      std       min     25%      50%     75%  \
# codcompany      33877.0     9.59     8.01      1.00     5.0     5.00    21.0
# quantity        33877.0    76.79   864.55 -20340.00     1.0     1.58    10.0
# saleamount      33877.0   878.71  3954.76 -87219.60     0.0    76.00   420.0
# typeline        33877.0     0.00     0.06      0.00     0.0     0.00     0.0
# costamount      33877.0   704.06  3391.61 -77772.88     3.0    51.85   314.5
# amountdiscount  33877.0     0.00     0.00      0.00     0.0     0.00     0.0
# codcustomer     33877.0  5579.82  2409.21      5.00  3451.0  6195.00  7447.0
# codvouchertype  33877.0    10.35     1.83     10.00    10.0    10.00    10.0
#
#                       max
# codcompany          21.00
# quantity         32000.00
# saleamount      190541.50
# typeline             2.00
# costamount      145717.34
# amountdiscount       0.00
# codcustomer       8783.00
# codvouchertype      31.00

# %% [markdown]
# ## Interpretación general de las variables numéricas
#
# -codcompany	Rango de valores entre 1 y 21. La media es 9.82, lo cual sugiere que hay varias empresas (probablemente 21) en el dataset.
#
# -quantity	Valores negativos (mínimo = -133) y máximos extremos (6111), con una desviación estándar muy alta. Esto indica posibles outliers o errores de carga.
#
# -saleamount	También tiene valores negativos (mínimo = -8379), lo cual puede representar devoluciones o errores. Alta dispersión.
#
# -typeline	Todos los valores son 0, por lo tanto esta columna no aporta información útil (columna constante).
#
# -costamount	Mismos valores extremos negativos y máximos que SaleAmount. Alta dispersión. Necesita revisión por posibles errores.
#
# -amountdiscount	Todos los valores son 0. Columna sin variabilidad → prescindible, salvo que esperes descuentos y no estén cargados.
#
# -codcustomer	Parece un ID numérico, pero como la media y mediana están en rangos razonables, puede usarse para segmentar si representa clientes reales.
#
# -codvouchertype	La mayoría de los valores son 10 (25%, 50%, 75% = 10), pero hay un valor atípico de 30. Tal vez un tipo de comprobante especial o error.

# %% [markdown]
# ## Eliminamos Typeline y AmountDiscount ya que todos sus valores son cero y no aportan nada

# %%
df2=df.drop(columns=['typeline', 'amountdiscount'])

# %%
df2.head()
# Out:
#    codcompany  idcustomer      fecha         idarticle  quantity  saleamount  \
# 0           1  001-003451 2024-06-28  001-010a055050tr      86.0     1316.66
# 1           1  001-003451 2024-01-31  001-010a055050tr      50.0      705.00
# 2           1  001-003451 2024-10-31  001-010a055050tr       5.0       76.55
# 3           1  001-003451 2024-10-31  001-010a073650az       3.0       62.37
# 4           1  001-003451 2024-11-29  001-010a073650az      11.0      228.69
#
#    costamount                       idpaymentmethod  documento  codcustomer  \
# 0     1316.66  95839b62-ccc4-4a70-a894-012c7d43a5bb  24A060136         3451
# 1      705.00  95839b62-ccc4-4a70-a894-012c7d43a5bb  24A010160         3451
# 2       76.55  95839b62-ccc4-4a70-a894-012c7d43a5bb  24A100186         3451
# 3       62.37  95839b62-ccc4-4a70-a894-012c7d43a5bb  24A100186         3451
# 4      228.69  95839b62-ccc4-4a70-a894-012c7d43a5bb  24A110174         3451
#
#                                cliente  codvouchertype        tipoasiento  \
# 0  ENVASES DE GALICIA, S.A.U. (EGALSA)              10  VENTAS NACIONALES
# 1  ENVASES DE GALICIA, S.A.U. (EGALSA)              10  VENTAS NACIONALES
# 2  ENVASES DE GALICIA, S.A.U. (EGALSA)              10  VENTAS NACIONALES
# 3  ENVASES DE GALICIA, S.A.U. (EGALSA)              10  VENTAS NACIONALES
# 4  ENVASES DE GALICIA, S.A.U. (EGALSA)              10  VENTAS NACIONALES
#
#   codproductline         macrofamilia codproductfamily  \
# 0            MF6  Envases y Embalajes              F33
# 1            MF6  Envases y Embalajes              F33
# 2            MF6  Envases y Embalajes              F33
# 3            MF6  Envases y Embalajes              F33
# 4            MF6  Envases y Embalajes              F33
#
#                     familia codproductsubfamily      subfamilia
# 0  Sacos y Mallas Extruidas                 010  MALLA MOLUSCOS
# 1  Sacos y Mallas Extruidas                 010  MALLA MOLUSCOS
# 2  Sacos y Mallas Extruidas                 010  MALLA MOLUSCOS
# 3  Sacos y Mallas Extruidas                 010  MALLA MOLUSCOS
# 4  Sacos y Mallas Extruidas                 010  MALLA MOLUSCOS

# %% [markdown]
# ## Histogramas

# %%
pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in c:\users\smp\appdata\local\programs\python\python313\lib\site-packages (3.10.7)
# Requirement already satisfied: seaborn in c:\users\smp\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\smp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\smp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\smp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\smp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\smp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\smp\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\smp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\smp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\smp\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\smp\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\smp\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\smp\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\smp\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
columnas_num=df2.select_dtypes(include=['number']).columns.tolist()

# %%
for col in columnas_num:
    plt.figure()
    sns.histplot(df2[col], kde=True)
    plt.show()

# %% [markdown]
# ## Boxplots

# %%
for col in columnas_num:
    plt.figure(figsize=(10, 1))
    sns.boxplot(x=df2[col])
    plt.show()

# %% [markdown]
# ## Columnas Categóricas

# %%
df2.describe(include=['category', 'object']).T
# Out:
#                      count unique                             top   freq
# idcustomer           33877   1848                      021-006150   3735
# idarticle            33877   5071                          021-lm   3032
# idpaymentmethod      33877    159                          021-91   3725
# documento            33877   4286                       24A120123    108
# cliente              33877   1640             FORMATO VERDE, S.L.   3735
# tipoasiento          33877      7               VENTAS NACIONALES  27985
# codproductline       33877     22                             MF6   8880
# macrofamilia         33877     18             Envases y Embalajes   8880
# codproductfamily     33877     55                           FC02C   4749
# familia              33877     52                Material Diverso   5050
# codproductsubfamily  33877    229                              AS   4702
# subfamilia           33877    243  ARTICULOS SIN CONTROL DE STOCK   4702

# %%
columnas_cat=df2.select_dtypes(include=['category', 'object']).columns.tolist()

# %%
columnas_cat
# Out:
# ['idcustomer',
#  'idarticle',
#  'idpaymentmethod',
#  'documento',
#  'cliente',
#  'tipoasiento',
#  'codproductline',
#  'macrofamilia',
#  'codproductfamily',
#  'familia',
#  'codproductsubfamily',
#  'subfamilia']

# %%
for col in columnas_cat:
    print(f"\nColumna: {col}")
    print(df2[col].value_counts())
# Out:
# Columna: idcustomer
# idcustomer
# 021-006150                              3735
# 005-001207                               919
# 001-003451                               836
# 021-006195                               763
# 005-003147                               750
#                                         ...
# bafc94fd-bd3a-4536-991f-a1c10c4ee357       1
# 28512469-911c-478c-b09e-90186daa7222       1
# 020dfdc4-29da-49ab-898f-e082ef18fc99       1
# 959d53f0-32a8-47a0-9758-d7ced79b881a       1
# 697aba92-b526-4336-ba71-a1d9a6740ffb       1
# Name: count, Length: 1848, dtype: int64
#
# Columna: idarticle
# idarticle
# 021-lm                                  3032
# 005-lm                                  1654
# 005-199012                              1240
# 005-199s001                              890
# 021-ys8810                               750
#                                         ...
# fddf2512-6949-4b5a-8df7-2e03a3d973ed       1
# 005-ecb3168                                1
# ff772887-8034-4794-a7fa-a3cb9671ceb6       1
# fd1220cb-ff16-4c6a-ad6b-524fa705c949       1
# fe900627-e3d4-4918-b698-cc4b9ef99759       1
# Name: count, Length: 5071, dtype: int64
#
# Columna: idpaymentmethod
# idpaymentmethod
# 021-91      3725
# 005-1-1     1890
# 005-17-1    1834
# 005-6-1     1745
# 005-33-1    1321
#             ...
# 001-80         1
# 005-86-1       1
# 001-91         1
# 001-93         1
# 021-17         1
# Name: count, Length: 159, dtype: int64
#
# Columna: documento
# documento
# 24A120123    108
# 24R080003     97
# 24S080016     91
# 24S070012     91
# 24S120079     88
#             ...
# 24A040212      1
# 24A010176      1
# 24S010031      1
# 24A050197      1
# 24A010178      1
# Name: count, Length: 4286, dtype: int64
#
# Columna: cliente
# cliente
# FORMATO VERDE, S.L.                          3735
# ENVASES DE GALICIA, S.A.U. (EGALSA)           996
# AMEGROVE SDAD. COOP. GALEGA                   952
# DESARROLLO DISEÑO & STYLING, S.L.U. (DDS)     766
# MARESMAR, S.L.U.                              750
#                                              ...
# MEJILLONES ROSGAR, S.L.                         1
# TALLERES PAINCEIRA, S.L.                        1
# LORENZO GONZALEZ, JUAN                          1
# CORSA PETFOOD, S.L.                             1
# GOMEZ BOTICARIO, PABLO                          1
# Name: count, Length: 1640, dtype: int64
#
# Columna: tipoasiento
# tipoasiento
# VENTAS NACIONALES                             27985
# VENTAS INTRACOMUNITARIAS                       4613
# VENTAS EXPORTACIONES                            634
# VENTAS EXPORTACION                              249
# VENTAS ARRENDAMIENTO (No Sujeto Retención)      199
# VENTAS EXENTAS                                  147
# VENTAS ARRENDAMIENTO (Sujeto Retención)          50
# Name: count, dtype: int64
#
# Columna: codproductline
# codproductline
# MF6      8880
# MFC02    4754
# MF8      4478
# MF12     3439
# MFR01    2640
# MF5      2605
# MFR03    1685
# MFC01    1157
# MFR05    1095
# MF3       665
# MF1       555
# MFR04     545
# MFR06     372
# MFR02     296
# MF00      194
# MF9       148
# MFA01     134
# MFA02     120
# MF7        80
# MF11       20
# MF4        10
# MFC03       5
# Name: count, dtype: int64
#
# Columna: macrofamilia
# macrofamilia
# Envases y Embalajes                     8880
# Varios                                  8193
# Maquinaria y SAT                        4556
# Custom Molding                          2640
# Efectos Navales                         2605
# Consumo Interno                         1712
# Manutención                             1685
# Varios Rotogal                          1011
# Consumibles Miticultura                  665
# Marine                                   467
# Calderería Plastica y Metálica           372
# Servicios Grupo y Administración         328
# Vruma                                    296
# Fotovoltaica                             200
# Reciclaje y valorización de Residuos     153
# Varios Egalsa                             84
# Stocks                                    20
# Contenedores y Pallets                    10
# Name: count, dtype: int64
#
# Columna: codproductfamily
# codproductfamily
# FC02C    4749
# F35      4375
# F13      3458
# F36      3138
# F33      2778
# FR01A    2272
# F1       1106
# FR03A    1098
# FC01C    1073
# FR05B    1007
# F15       906
# F37       702
# F34       683
# F7        594
# F8        555
# F30       545
# FR03B     472
# FR04B     399
# FR06A     339
# F24       301
# F2        280
# F12       262
# F32       243
# FR01B     212
# FR02B     202
# F00       194
# F17       171
# FR01V     156
# F5        141
# FA01A     134
# FA02A     120
# F10       120
# F16       103
# F4         95
# FR02A      94
# F23        88
# FR05A      88
# FC01B      84
# F18        80
# FR04D      78
# FR03C      76
# FR04A      68
# F14        58
# F31        46
# FR03D      39
# FR06B      33
# F19        20
# F22        14
# F9         10
# F28         6
# FC03A       5
# FC02A       4
# F21         1
# F29         1
# FC02D       1
# Name: count, dtype: int64
#
# Columna: familia
# familia
# Material Diverso                     5050
# Consumibles SAT                      4375
# Envases Madera                       3458
# Servicios Varios                     3138
# Sacos y Mallas Extruidas             2778
# Formato Verde                        2272
# Cabos y Estachas                     1106
# Bins                                 1098
# Componentes y Accesorios             1073
# Servicios Rotogal                     923
# Envases Plasticos Rigidos             906
# Suministros Varios                    702
# Sacos y Mallas Tejidas                683
# Consumibles Envasado                  594
# Consumo Interno y componentes         555
# Red de Algodón                        545
# Tapas                                 472
# Nautica Deportiva                     399
# Calderería Plástica                   339
# Servicios Grupo y Administración      328
# Cadenas, Anclas y Grilletes           280
# Embalaje                              262
# Redes                                 243
# DDS                                   212
# Equipamiento                          202
# Fotovoltaica                          200
# Flotación Pesca                       171
# Varios Custom                         156
# Clichés Impresión                     141
# Cuerdas Cultivo Mejillón              120
# Flotación Acuicultura y Fondeos       103
# Chatarra y Residuos                   100
# Embarcaciones                          94
# Maquinaria planta proceso              88
# Poductos Rotogal                       88
# Materias Primas                        84
# Servicios Egalsa                       84
# Servicios SAT                          78
# Pallets                                76
# Acuicultura y pesca                    68
# Envases Plasticos Alimentación         58
# Red Reciclaje                          46
# Otros Productos                        39
# Calderería Metálica                    33
# Grandes Lotes                          20
# Maquinaria Depuración y Estocaje       14
# Contenedores Rotomoldeo                10
# Plomo                                   6
# Otros consumibles (No inventario)       4
# Maquinaria Barco                        1
# Plomo y Metales                         1
# Caducados                               1
# Name: count, dtype: int64
#
# Columna: codproductsubfamily
# codproductsubfamily
# AS      4702
# SVP     2147
# 199S    1697
# 020     1616
# ECB     1595
#         ...
# ZCAD       1
# 054        1
# 52         1
# 008        1
# AP5        1
# Name: count, Length: 229, dtype: int64
#
# Columna: subfamilia
# subfamilia
# ARTICULOS SIN CONTROL DE STOCK    4702
# PORTES                            2147
# SERVICIOS VARIOS SAT              1775
# SACOS                             1616
# REPUESTOS ECONOMY BAG             1595
#                                   ...
# REPUESTOS FLEJADORA SMG75I           1
# CABO ALGODON                         1
# CONSUMIBLES PALLETS NESTLE           1
# GEOMALLA (MALLA PLANA)               1
# ACUICULTURA "BRAQUETS"               1
# Name: count, Length: 243, dtype: int64

# %% [markdown]
# ## Crear columnas de fecha (año, mes, mes-año) para agrupar y comparar con el presupuesto mensual.

# %%
df['fecha'] = pd.to_datetime(df['fecha'], errors='coerce', dayfirst=True)

# %%
df['year'] = df['fecha'].dt.year
df['month'] = df['fecha'].dt.month
df['month_name'] = df['fecha'].dt.strftime('%Y-%m')  # formato '2024-07

# %% [markdown]
# ## Exportar datos

# %%
df2.head()
# Out:
#    codcompany  idcustomer      fecha         idarticle  quantity  saleamount  \
# 0           1  001-003451 2024-06-28  001-010a055050tr      86.0     1316.66
# 1           1  001-003451 2024-01-31  001-010a055050tr      50.0      705.00
# 2           1  001-003451 2024-10-31  001-010a055050tr       5.0       76.55
# 3           1  001-003451 2024-10-31  001-010a073650az       3.0       62.37
# 4           1  001-003451 2024-11-29  001-010a073650az      11.0      228.69
#
#    costamount                       idpaymentmethod  documento  codcustomer  \
# 0     1316.66  95839b62-ccc4-4a70-a894-012c7d43a5bb  24A060136         3451
# 1      705.00  95839b62-ccc4-4a70-a894-012c7d43a5bb  24A010160         3451
# 2       76.55  95839b62-ccc4-4a70-a894-012c7d43a5bb  24A100186         3451
# 3       62.37  95839b62-ccc4-4a70-a894-012c7d43a5bb  24A100186         3451
# 4      228.69  95839b62-ccc4-4a70-a894-012c7d43a5bb  24A110174         3451
#
#                                cliente  codvouchertype        tipoasiento  \
# 0  ENVASES DE GALICIA, S.A.U. (EGALSA)              10  VENTAS NACIONALES
# 1  ENVASES DE GALICIA, S.A.U. (EGALSA)              10  VENTAS NACIONALES
# 2  ENVASES DE GALICIA, S.A.U. (EGALSA)              10  VENTAS NACIONALES
# 3  ENVASES DE GALICIA, S.A.U. (EGALSA)              10  VENTAS NACIONALES
# 4  ENVASES DE GALICIA, S.A.U. (EGALSA)              10  VENTAS NACIONALES
#
#   codproductline         macrofamilia codproductfamily  \
# 0            MF6  Envases y Embalajes              F33
# 1            MF6  Envases y Embalajes              F33
# 2            MF6  Envases y Embalajes              F33
# 3            MF6  Envases y Embalajes              F33
# 4            MF6  Envases y Embalajes              F33
#
#                     familia codproductsubfamily      subfamilia
# 0  Sacos y Mallas Extruidas                 010  MALLA MOLUSCOS
# 1  Sacos y Mallas Extruidas                 010  MALLA MOLUSCOS
# 2  Sacos y Mallas Extruidas                 010  MALLA MOLUSCOS
# 3  Sacos y Mallas Extruidas                 010  MALLA MOLUSCOS
# 4  Sacos y Mallas Extruidas                 010  MALLA MOLUSCOS

# %%
df2.to_csv("C:/Users/smp/OneDrive - Grupo JJChicolino/THE POWER/PROYECTOFINALEDA/data/output/ventas2024_limpio.csv", index=False)
