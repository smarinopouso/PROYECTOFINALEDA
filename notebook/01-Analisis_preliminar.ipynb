# %% [markdown]
# ## Importación de Librerías

# %%
import pandas as pd

# %% [markdown]
# ## Carga de datos

# %%
df = pd.read_csv(
    r"C:/Users/smp/OneDrive - Grupo JJChicolino/THE POWER/PROYECTOFINALEDA/data/raw/ventas2024.csv",
    sep=";",
    encoding="latin1",     # prueba esta primera
    on_bad_lines="skip",
    decimal=",", 
    parse_dates=["Fecha"]  # intenta convertir 'Fecha' a datetime
)

# %%
df.sample(50)
# Out:
#      ï»¿codcompany                            IdCustomer       Fecha  \
# 140              5                            005-001207  15/11/2024
# 45              21  45f6d6de-ed03-4059-8e02-18b1e245e85a  08/02/2024
# 18              21                            021-006195  29/11/2024
# 63               5  19fcde6a-28ab-46b6-b979-da7503f460e7  25/11/2024
# 30               5                            005-007199  26/06/2024
# 49               1  eb395f0c-ffdf-4bc7-93e3-0c23c4e74505  09/12/2024
# 26               1                            001-003899  03/10/2024
# 198              5                            005-001208  29/01/2024
# 51              21                            021-007021  12/06/2024
# 120             21  8ea430a4-0b92-48f8-a40c-6d3c8e98ad21  05/07/2024
# 12               5                            005-003623  30/08/2024
# 117              5                            005-003623  15/04/2024
# 53               5                            005-006952  19/07/2024
# 14               1                            001-002668  30/09/2024
# 186              5  c23bfd3e-8dc4-498e-9dbd-9fb451d8fde5  09/08/2024
# 110              5  b2f0bcc6-cfbe-471d-b7be-c8e19e4e9ff4  24/12/2024
# 23               1                            001-006575  16/09/2024
# 2               21  cf120b8c-3216-4c79-9138-5fc8a6e8ac42  09/08/2024
# 173              5                            005-003318  30/12/2024
# 191              5  f77a1509-df7d-4149-9084-d332ab2d13d4  31/01/2024
# 10               5                            005-001197  31/01/2024
# 132             21                            021-006195  07/06/2024
# 124              5                            005-001237  22/08/2024
# 68               5                            005-003147  31/07/2024
# 82               1  e86e3413-3dcd-45c6-93c9-9290b5e0a941  01/02/2024
# 98               5  ee6139cd-0b6c-49e5-a7e5-a77f072418e8  18/03/2024
# 142             21                            021-006919  18/12/2024
# 101              5  054c70cf-8b4f-47c3-bab2-4e06a05168cb  15/11/2024
# 46               5                            005-003756  31/05/2024
# 199              5  9a31b211-c35f-4c27-b77f-3d2c9f23e32f  08/03/2024
# 6                5                            005-000554  26/12/2024
# 20               5  ffa17dc0-bc15-467a-b987-323c79dcda8e  23/05/2024
# 79              21  cdb05634-ce98-4667-997c-c7c77fa2cfa0  01/07/2024
# 133              1  ac552b3b-ef11-4034-b397-e75ee849b23f  09/12/2024
# 24               5                            005-001315  19/07/2024
# 192              5                            005-003147  10/07/2024
# 121             21                            021-006150  22/04/2024
# 115              5  09d612c2-af91-4213-bde2-6ca35a15e095  29/04/2024
# 149             21  4725c681-b2cd-43d5-a72a-ac607cb8bb00  05/12/2024
# 135              1                            001-000376  22/11/2024
# 84               5                            005-004525  21/11/2024
# 119              5                            005-006163  24/04/2024
# 128              1                            001-003451  28/06/2024
# 172              5                            005-006196  18/03/2024
# 183              1  c2ac2ab2-72a0-4591-8726-e9a2d6a079ae  26/11/2024
# 96              21                            021-006150  03/04/2024
# 169              5                            005-001219  30/10/2024
# 116             21                            021-002934  30/09/2024
# 59               1                            001-003451  30/09/2024
# 86              21  3023c588-921c-4e5d-9ae6-ed8d3ebbb0bf  19/07/2024
#
#                                 IDArticle  Quantity  SaleAmount  TypeLine  \
# 140                           005-199s001     1.500       57.75         0
# 45   07b3c3eb-6b5c-438b-9c99-d29632f62bca     1.000       95.00         0
# 18                                 021-lm     1.000        0.00         0
# 63                       005-010a093650am     2.000       87.10         0
# 30                             005-199012     1.000      160.00         0
# 49                             001-101303     2.000       80.00         0
# 26                              001-22301    54.000      464.40         0
# 198                           005-pmc2051     1.000      116.00         0
# 51                                 021-lm     1.000      210.00         0
# 120                            021-47tp06    15.000       86.25         0
# 12                         005-133g03md01     0.480      545.28         0
# 117                        005-132a04md04     0.500      448.50         0
# 53   ac5fab1c-0e19-47bd-8138-ef28646deeb0     0.162      340.20         0
# 14                           001-210b75ac    10.000     1920.00         0
# 186  664f32e7-0b4d-4123-95c6-c1cbb0683b91     6.000       31.20         0
# 110                      005-010a104670ne     2.000       84.80         0
# 23                             001-068541   150.000      375.00         0
# 2    40f44bd8-44d8-4fc9-b55c-c62d9e53cdfe    10.000      283.40         0
# 173                          005-grn88123     1.000       30.00         0
# 191                           005-199s003     2.000       42.00         0
# 10                        005-ttorc55038i     2.000        0.20         0
# 132  af29ad9b-b764-4bb1-a4c1-a64b1a3a5cb9     1.000      301.34         0
# 124                        005-020a7035ne    10.000     1590.00         0
# 68                              005-32615     6.000        0.00         0
# 82                          001-0813a2000     2.000       24.00         0
# 98                                 005-lm     1.000        0.00         0
# 142                            021-47gr01     3.000       45.00         0
# 101                          005-130a1600     0.030       66.00         0
# 46   af2a4ed0-b50a-4932-bb0c-8a39e8dd6ad8    12.000      210.00         0
# 199                    005-010a093650amta   700.000    19635.00         0
# 6    4b787623-6e0d-4557-b19b-d0bef1b894fe   304.000      422.56         0
# 20                             005-199012     1.000        5.00         0
# 79                             021-47ll01     1.000        0.00         0
# 133  5469d04a-29dc-4ef3-85d8-0c47aecd4e27     5.000      126.75         0
# 24                         005-020a5030am     2.000      224.00         0
# 192  202cbcea-b5e5-40ef-9d13-d19da2a54ec6     2.730     4340.70         0
# 121  df3d119d-ad19-4283-9c2d-32be32f611b4    18.000      945.54         0
# 115                        005-020a7030ro     2.000      300.00         0
# 149                                021-lm     1.000        0.00         0
# 135                          001-106b0t04     1.000       26.50         0
# 84                                 005-lm     1.000        0.00         0
# 119                            005-140b11    10.000       45.10         0
# 128                      001-010a104670bl   160.000     3945.60         0
# 172                           005-199s001     1.250        0.00         0
# 183  b152be1d-9a98-44fd-9c53-005860497add   500.000       36.00         0
# 96                             021-73se01   200.000      174.24         0
# 169                          005-130a1000     0.500      535.00         0
# 116  3eab43e8-0262-48f9-a9a5-73a12ab69a96    98.000    14798.00         0
# 59   bd38dcd0-bcfa-485f-9119-743737aba24e   144.300    19408.35         0
# 86   a1bf2147-a9cb-4ccb-a0a8-2f8965d18dd3     1.000      499.00         0
#
#       CostAmount  AmountDiscount                       IDPaymentMethod  ...  \
# 140     27.00000               0                              005-83-1  ...
# 45      88.43000               0                                021-36  ...
# 18       0.00000               0                                021-33  ...
# 63      58.22000               0                              005-33-1  ...
# 30     155.81000               0                              005-33-1  ...
# 49      36.20000               0                                001-90  ...
# 26     321.51438               0                                001-83  ...
# 198     80.80000               0                              005-42-1  ...
# 51     166.17000               0                                021-38  ...
# 120     53.66280               0                                021-21  ...
# 12     265.23840               0                              005-87-1  ...
# 117    243.42000               0                              005-87-1  ...
# 53     149.19390               0                              005-33-1  ...
# 14    1636.20000               0                                001-87  ...
# 186     21.83208               0  e250d566-d119-4a2f-a52d-4b0ed5975e1b  ...
# 110     56.78000               0                              005-33-1  ...
# 23      76.69650               0                                001-94  ...
# 2      188.00000               0                                 021-6  ...
# 173     22.37300               0                               005-3-1  ...
# 191     26.00000               0                               005-4-1  ...
# 10       0.14000               0                              005-89-1  ...
# 132    165.99000               0                                021-37  ...
# 124   1118.30000               0                              005-82-1  ...
# 68      18.00000               0                              005-81-1  ...
# 82       0.94800               0                                001-90  ...
# 98       0.00000               0  8cf39cbb-bd3e-4186-92ad-94d138df1ba4  ...
# 142      4.65000               0                                021-21  ...
# 101     27.19170               0                              005-90-1  ...
# 46     122.76432               0                               005-4-1  ...
# 199  11907.00000               0  3583178e-7085-4500-bbdb-8c55cb87c70d  ...
# 6      329.69408               0                               005-1-1  ...
# 20       3.50000               0                               005-1-1  ...
# 79       2.39378               0                                021-33  ...
# 133     75.16770               0                                001-31  ...
# 24     164.86000               0                               005-6-1  ...
# 192   2116.43250               0                              005-81-1  ...
# 121   1274.58000               0                                021-91  ...
# 115    212.44000               0                               005-6-1  ...
# 149      0.00000               0                                021-65  ...
# 135     18.43444               0                                001-90  ...
# 84       0.00000               0                              005-17-1  ...
# 119     18.72630               0                             005-100-1  ...
# 128   3945.60000               0  95839b62-ccc4-4a70-a894-012c7d43a5bb  ...
# 172     18.75000               0                              005-17-1  ...
# 183     26.00000               0                                001-90  ...
# 96     116.16000               0                                021-91  ...
# 169    286.02000               0                               005-6-1  ...
# 116   7350.00000               0                                 021-4  ...
# 59   19408.35000               0  95839b62-ccc4-4a70-a894-012c7d43a5bb  ...
# 86       0.00000               0                                021-33  ...
#
#     CODCUSTOMER                                            Cliente  \
# 140        1207                        AMEGROVE SDAD, COOP, GALEGA
# 45         7467                       INKA PRESSWOOD PALLETS; LTD,
# 18         6195         DESARROLLO DISEÃO & STYLING; S,L,U, (DDS)
# 63         7834                                   ACTIVETASTE LDA,
# 30         7199              MUGEN - CONSULTORES; UNIPESSOAL; LDA,
# 49         7901                            GIL AIZPURU; JOSE MARIA
# 26         3899                             DUARTE GONZALEZ; PAULO
# 198        1208                         MOLUSCOS RIAS BAIXAS; S,A,
# 51         7021                               ROTOGAL BENELUX B,V,
# 120        7730                 COFRADIA DE PESCADORES DE DELTEBRE
# 12         3623                             MARISCOS DAPORTA; S,L,
# 117        3623                             MARISCOS DAPORTA; S,L,
# 53         6952                 LA QUESERIA; C,B, (QUESERIA GIJON)
# 14         2668             EFECTOS NAVALES Y DEPORTES O MAR; S,L,
# 186        8169                                     UKUTITEC; S,L,
# 110        8222                                    TRONCOMAR; S,L,
# 23         6575                                LAGO DE LOURO; LDA,
# 2          7137                  RONAUTICA QUALITY MARINAS; S,L,U,
# 173        3318         RAMIRO MARTINEZ; S,L, (EMBUTIDOS MONTIÃO)
# 191        8102                           LAMAZARES HERMIDA; MARCO
# 10         1197  DEPURADORA DE MARISCOS DE LORBE; S,A, (DEMARLOSA)
# 132        6195         DESARROLLO DISEÃO & STYLING; S,L,U, (DDS)
# 124        1237                             MARISCOS CAMPELO; S,A,
# 68         3147                                   MARESMAR; S,L,U,
# 82         7877                   VARELA ROMERO; IGNACIO ALEJANDRO
# 98         7750                           ANGULAS AGUINAGA; S,A,U,
# 142        6919  FRIGORIFICOS INDUSTRIALES DEL BIERZO; S,A, (EM...
# 101        7844                                     SUMPTUOS; S,C,
# 46         3756  XUNTA DE GALICIA - INSTITUTO GALEGO DE FORMACI...
# 199        7867                             F & M ECOENVASES; S,L,
# 6           554                              MARISCOS CORDAL; S,L,
# 20         7249                                        GISVA; S,A,
# 79         8539                              VALLE ECHEVARRIA;S,L,
# 133        7989                               ISTRIDA D,O,O, POREC
# 24         1315                              MARISCOS JOYFRA; S,L,
# 192        3147                                   MARESMAR; S,L,U,
# 121        6150                                FORMATO VERDE; S,L,
# 115        7770                             MARISCOS EL CABO; S,L,
# 149        8586                           MARINE INSTRUMENTS; S,A,
# 135         376                               FACTURA SIMPLIFICADA
# 84         4525                FALCAMAR-COMERCIO DE MARISCOS; LDA,
# 119        6163                         VIÃAS LOJO; LUIS SANTIAGO
# 128        3451                ENVASES DE GALICIA; S,A,U, (EGALSA)
# 172        6196                                 O PERCEBEIRO; S,L,
# 183        7883                          BATEA CAMBADESA III; C,B,
# 96         6150                                FORMATO VERDE; S,L,
# 169        1219                                     VENGARCO; S,L,
# 116        2934                             J,J, CHICOLINO; S,L,U,
# 59         3451                ENVASES DE GALICIA; S,A,U, (EGALSA)
# 86         8704                         ADANEZ GARCIA; JOSE MANUEL
#
#     CODVOUCHERTYPE               tipoasiento CODPRODUCTLINE  \
# 140             10         VENTAS NACIONALES           MF12
# 45              12      VENTAS EXPORTACIONES          MFR03
# 18              10         VENTAS NACIONALES          MFC02
# 63              11  VENTAS INTRACOMUNITARIAS            MF6
# 30              11  VENTAS INTRACOMUNITARIAS           MF12
# 49              10         VENTAS NACIONALES            MF5
# 26              10         VENTAS NACIONALES            MF5
# 198             10         VENTAS NACIONALES            MF8
# 51              11  VENTAS INTRACOMUNITARIAS          MFC02
# 120             10         VENTAS NACIONALES          MFC01
# 12              10         VENTAS NACIONALES            MF6
# 117             10         VENTAS NACIONALES            MF6
# 53              10         VENTAS NACIONALES            MF6
# 14              10         VENTAS NACIONALES            MF3
# 186             10         VENTAS NACIONALES          MFC02
# 110             10         VENTAS NACIONALES            MF6
# 23              11  VENTAS INTRACOMUNITARIAS            MF5
# 2               10         VENTAS NACIONALES          MFR04
# 173             10         VENTAS NACIONALES            MF8
# 191             10         VENTAS NACIONALES           MF12
# 10              10         VENTAS NACIONALES            MF8
# 132             10         VENTAS NACIONALES          MFR01
# 124             10         VENTAS NACIONALES            MF6
# 68              10         VENTAS NACIONALES            MF1
# 82              10         VENTAS NACIONALES            MF5
# 98              10         VENTAS NACIONALES          MFC02
# 142             10         VENTAS NACIONALES          MFC01
# 101             10         VENTAS NACIONALES            MF6
# 46              10         VENTAS NACIONALES            MF8
# 199             10         VENTAS NACIONALES            MF6
# 6               10         VENTAS NACIONALES            MF6
# 20              10         VENTAS NACIONALES           MF12
# 79              10         VENTAS NACIONALES          MFC01
# 133             11  VENTAS INTRACOMUNITARIAS            MF5
# 24              10         VENTAS NACIONALES            MF6
# 192             10         VENTAS NACIONALES            MF6
# 121             10         VENTAS NACIONALES          MFR01
# 115             10         VENTAS NACIONALES            MF6
# 149             10         VENTAS NACIONALES          MFC02
# 135             10         VENTAS NACIONALES            MF5
# 84              11  VENTAS INTRACOMUNITARIAS          MFC02
# 119             10         VENTAS NACIONALES            MF6
# 128             10         VENTAS NACIONALES            MF6
# 172             10         VENTAS NACIONALES           MF12
# 183             10         VENTAS NACIONALES            MF5
# 96              10         VENTAS NACIONALES          MFC01
# 169             10         VENTAS NACIONALES            MF6
# 116             10         VENTAS NACIONALES          MFR04
# 59              10         VENTAS NACIONALES            MF6
# 86              10         VENTAS NACIONALES          MFR02
#
#                 macrofamilia CODPRODUCTFAMILY                        familia  \
# 140                   Varios              F36               Servicios Varios
# 45              ManutenciÃ³n            FR03B                          Tapas
# 18                    Varios            FC02C               Material Diverso
# 63       Envases y Embalajes              F33       Sacos y Mallas Extruidas
# 30                    Varios              F36               Servicios Varios
# 49           Efectos Navales              F17               FlotaciÃ³n Pesca
# 26           Efectos Navales              F37             Suministros Varios
# 198         Maquinaria y SAT              F35                Consumibles SAT
# 51                    Varios            FC02C               Material Diverso
# 120          Consumo Interno            FC01C       Componentes y Accesorios
# 12       Envases y Embalajes              F13                 Envases Madera
# 117      Envases y Embalajes              F13                 Envases Madera
# 53       Envases y Embalajes              F13                 Envases Madera
# 14   Consumibles Miticultura              F30                Red de AlgodÃ³n
# 186                   Varios            FC02C               Material Diverso
# 110      Envases y Embalajes              F33       Sacos y Mallas Extruidas
# 23           Efectos Navales              F32                          Redes
# 2                     Marine            FR04B              Nautica Deportiva
# 173         Maquinaria y SAT              F35                Consumibles SAT
# 191                   Varios              F36               Servicios Varios
# 10          Maquinaria y SAT              F35                Consumibles SAT
# 132           Custom Molding            FR01B                            DDS
# 124      Envases y Embalajes              F33       Sacos y Mallas Extruidas
# 68           Consumo Interno               F8  Consumo Interno y componentes
# 82           Efectos Navales               F2    Cadenas; Anclas y Grilletes
# 98                    Varios            FC02C               Material Diverso
# 142          Consumo Interno            FC01C       Componentes y Accesorios
# 101      Envases y Embalajes              F13                 Envases Madera
# 46          Maquinaria y SAT              F35                Consumibles SAT
# 199      Envases y Embalajes              F33       Sacos y Mallas Extruidas
# 6        Envases y Embalajes              F15      Envases Plasticos Rigidos
# 20                    Varios              F36               Servicios Varios
# 79           Consumo Interno            FC01C       Componentes y Accesorios
# 133          Efectos Navales              F37             Suministros Varios
# 24       Envases y Embalajes              F33       Sacos y Mallas Extruidas
# 192      Envases y Embalajes              F13                 Envases Madera
# 121           Custom Molding            FR01A                  Formato Verde
# 115      Envases y Embalajes              F33       Sacos y Mallas Extruidas
# 149                   Varios            FC02C               Material Diverso
# 135          Efectos Navales              F37             Suministros Varios
# 84                    Varios            FC02C               Material Diverso
# 119      Envases y Embalajes               F7           Consumibles Envasado
# 128      Envases y Embalajes              F33       Sacos y Mallas Extruidas
# 172                   Varios              F36               Servicios Varios
# 183          Efectos Navales              F37             Suministros Varios
# 96           Consumo Interno            FC01C       Componentes y Accesorios
# 169      Envases y Embalajes              F13                 Envases Madera
# 116                   Marine            FR04A            Acuicultura y pesca
# 59       Envases y Embalajes              F33       Sacos y Mallas Extruidas
# 86                     Vruma            FR02A                  Embarcaciones
#
#     CODPRODUCTSUBFAMILY                                subfamilia
# 140                199S                      SERVICIOS VARIOS SAT
# 45                  110                             TAPAS BIN PUR
# 18                   AS            ARTICULOS SIN CONTROL DE STOCK
# 63                   10                            MALLA MOLUSCOS
# 30                  SVP                                    PORTES
# 49                 1013                       BOYAS TIPO POLYFORM
# 26                  223      PROD, RODEAR RED TUBULAR (NO PROPIO)
# 198                 PMC          REPUESTOS PESADORAS MULTICABEZAL
# 51                   AS            ARTICULOS SIN CONTROL DE STOCK
# 120                  51                          CONSUMIBLES BINS
# 12                  133                    CAIXAS RECTAS CLASICAS
# 117                 132            BARCAS BISELADAS PLASTIFICADAS
# 53                  133                    CAIXAS RECTAS CLASICAS
# 14                  210                               COTTON PLUS
# 186                  MD                          MATERIAL DIVERSO
# 110                  10                            MALLA MOLUSCOS
# 23                  685       RED ARRASTRE CERRADA Y NORMAL USADA
# 2                   ND2                   COMPLEMENTOS PANTALANES
# 173                 GRN            REPUESTOS GRAP, NEUMATICA AN-1
# 191                199S                      SERVICIOS VARIOS SAT
# 10                    T                     REPUESTOS TORNILLERIA
# 132                 CB2                     PLATAFORMAS BARRACUDA
# 124                  20                                     SACOS
# 68                   32         CAJAS-MATERIA PRIMA - COMPONENTES
# 82                  813                           HERRAJES VARIOS
# 98                   AS            ARTICULOS SIN CONTROL DE STOCK
# 142                  51                          CONSUMIBLES BINS
# 101                 130                           BARCAS CLASICAS
# 46                   ED    REPUESTOS EQUIPO DEPURACION Y ESTOCAJE
# 199                  10                            MALLA MOLUSCOS
# 6                   160                        CAJAS POLIESTIRENO
# 20                  SVP                                    PORTES
# 79                   51                          CONSUMIBLES BINS
# 133                  49                              OSTRICULTURA
# 24                   20                                     SACOS
# 192                 130                           BARCAS CLASICAS
# 121                 CA4                                     TAPAS
# 115                  20                                     SACOS
# 149                  AS            ARTICULOS SIN CONTROL DE STOCK
# 135                 106                     ROPA DE AGUAS Y BOTAS
# 84                   AS            ARTICULOS SIN CONTROL DE STOCK
# 119                 140  PROD, COMPL,: ALAMBRES; GRAPAS; ATALAZOS
# 128                  10                            MALLA MOLUSCOS
# 172                199S                      SERVICIOS VARIOS SAT
# 183                  41                  MATERIAL MEJILLON VARIOS
# 96                   65                      CONSUMIBLES EMBALAJE
# 169                 130                           BARCAS CLASICAS
# 116                 AP1                        FLOTADOR LONG-LINE
# 59                   20                                     SACOS
# 86                  V03                                    RECREO
#
# [50 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ï»¿codcompany        200 non-null    int64
#  1   IdCustomer           200 non-null    object
#  2   Fecha                200 non-null    object
#  3   IDArticle            200 non-null    object
#  4   Quantity             200 non-null    float64
#  5   SaleAmount           200 non-null    float64
#  6   TypeLine             200 non-null    int64
#  7   CostAmount           200 non-null    float64
#  8   AmountDiscount       200 non-null    int64
#  9   IDPaymentMethod      200 non-null    object
#  10  Documento            200 non-null    object
#  11  CODCUSTOMER          200 non-null    int64
#  12  Cliente              200 non-null    object
#  13  CODVOUCHERTYPE       200 non-null    int64
#  14  tipoasiento          200 non-null    object
#  15  CODPRODUCTLINE       200 non-null    object
#  16  macrofamilia         200 non-null    object
#  17  CODPRODUCTFAMILY     200 non-null    object
#  18  familia              200 non-null    object
#  19  CODPRODUCTSUBFAMILY  200 non-null    object
#  20  subfamilia           200 non-null    object
# dtypes: float64(3), int64(5), object(13)
# memory usage: 32.9+ KB

# %% [markdown]
# ## Columnas del dataset
#
# -ï»¿codcompany: Código identificador de la empresa
#
# -IdCustomer: Identificador del cliente
#
# -Fecha: Fecha de la transacción o venta
#
# -IDArticle: Código identificador del artículo o producto
#
# -Quantity: Cantidad vendida
#
# -SaleAmount: Importe de la venta
#
# -TypeLine: Tipo de línea o categoría de producto
#
# -CostAmount: Coste asociado a la venta
#
# -AmountDiscount: Monto del descuento aplicado
#
# -IDPaymentMethod: Identificador del método de pago
#
# -Documento: Número o código del documento o factura
#
# -CODCUSTOMER: Código numérico identificador del cliente
#
# -Cliente: Nombre del cliente
#
# -CODVOUCHERTYPE: Código del tipo de comprobante o voucher
#
# -tipoasiento: Tipo de asiento contable o asiento de la transacción
#
# -CODPRODUCTLINE: Código de la línea de producto
#
# -macrofamilia: Nombre de la macrofamilia
#
# -CODPRODUCTFAMILY: Código de la familia del producto
#
# -familia: Nombre de la familia del producto
#
# -CODPRODUCTSUBFAMILY: Código de la subfamilia del producto
#
# -subfamilia: Nombre de la subfamilia del producto

# %% [markdown]
# ## Columnas a corregir:
#
# -ï»¿codcompany renombrar a codcompany
#
# -AmountDiscount: es int64, está bien si solo hay descuentos enteros, pero si pueden ser decimales, mejor float.

# %%
df.rename(columns={'ï»¿codcompany': 'codcompany'}, inplace=True)

# %%
df['AmountDiscount'] = df['AmountDiscount'].astype(float)

# %%
print(df.columns.tolist())
# Out:
# ['codcompany', 'IdCustomer', 'Fecha', 'IDArticle', 'Quantity', 'SaleAmount', 'TypeLine', 'CostAmount', 'AmountDiscount', 'IDPaymentMethod', 'Documento', 'CODCUSTOMER', 'Cliente', 'CODVOUCHERTYPE', 'tipoasiento', 'CODPRODUCTLINE', 'macrofamilia', 'CODPRODUCTFAMILY', 'familia', 'CODPRODUCTSUBFAMILY', 'subfamilia']

# %% [markdown]
# ## Revisar nulos

# %%
df.isnull().sum()
# Out:
# codcompany             0
# IdCustomer             0
# Fecha                  0
# IDArticle              0
# Quantity               0
# SaleAmount             0
# TypeLine               0
# CostAmount             0
# AmountDiscount         0
# IDPaymentMethod        0
# Documento              0
# CODCUSTOMER            0
# Cliente                0
# CODVOUCHERTYPE         0
# tipoasiento            0
# CODPRODUCTLINE         0
# macrofamilia           0
# CODPRODUCTFAMILY       0
# familia                0
# CODPRODUCTSUBFAMILY    0
# subfamilia             0
# dtype: int64

# %% [markdown]
# ## Revisar duplicados

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Variables numéricas

# %%
columnas_num=df.select_dtypes(include=['number']).columns.tolist()

# %%
columnas_num
# Out:
# ['codcompany',
#  'Quantity',
#  'SaleAmount',
#  'TypeLine',
#  'CostAmount',
#  'AmountDiscount',
#  'CODCUSTOMER',
#  'CODVOUCHERTYPE']

# %%
df.describe(include='number').T.round(2)
# Out:
#                 count     mean      std     min      25%      50%      75%  \
# codcompany      200.0     9.82     8.06     1.0     5.00     5.00    21.00
# Quantity        200.0    53.06   437.30  -133.0     1.00     2.00    10.00
# SaleAmount      200.0  1098.86  5868.08 -8379.0     4.50    85.52   345.15
# TypeLine        200.0     0.00     0.00     0.0     0.00     0.00     0.00
# CostAmount      200.0   934.35  5626.91 -8379.0     4.46    51.05   217.46
# AmountDiscount  200.0     0.00     0.00     0.0     0.00     0.00     0.00
# CODCUSTOMER     200.0  5731.00  2264.91   376.0  3888.50  6194.00  7637.00
# CODVOUCHERTYPE  200.0    10.21     1.45    10.0    10.00    10.00    10.00
#
#                      max
# codcompany         21.00
# Quantity         6111.00
# SaleAmount      69152.99
# TypeLine            0.00
# CostAmount      69152.99
# AmountDiscount      0.00
# CODCUSTOMER      8777.00
# CODVOUCHERTYPE     30.00

# %% [markdown]
# ## Interpretación general de las variables numéricas
#
# -codcompany	Rango de valores entre 1 y 21. La media es 9.82, lo cual sugiere que hay varias empresas (probablemente 21) en el dataset.
#
# -Quantity	Valores negativos (mínimo = -133) y máximos extremos (6111), con una desviación estándar muy alta. Esto indica posibles outliers o errores de carga.
#
# -SaleAmount	También tiene valores negativos (mínimo = -8379), lo cual puede representar devoluciones o errores. Alta dispersión.
#
# -TypeLine	Todos los valores son 0, por lo tanto esta columna no aporta información útil (columna constante).
#
# -CostAmount	Mismos valores extremos negativos y máximos que SaleAmount. Alta dispersión. Necesita revisión por posibles errores.
#
# -AmountDiscount	Todos los valores son 0. Columna sin variabilidad → prescindible, salvo que esperes descuentos y no estén cargados.
#
# -CODCUSTOMER	Parece un ID numérico, pero como la media y mediana están en rangos razonables, puede usarse para segmentar si representa clientes reales.
#
# -CODVOUCHERTYPE	La mayoría de los valores son 10 (25%, 50%, 75% = 10), pero hay un valor atípico de 30. Tal vez un tipo de comprobante especial o error.

# %% [markdown]
# ## Eliminamos Typeline y AmountDiscount ya que todos sus valores son cero y no aportan nada

# %%
df.drop(columns=['TypeLine', 'AmountDiscount'])
# Out:
#      codcompany                            IdCustomer       Fecha  \
# 0            21                            021-006150  01/04/2024
# 1             5                            005-003623  31/12/2024
# 2            21  cf120b8c-3216-4c79-9138-5fc8a6e8ac42  09/08/2024
# 3             5  4190698d-d586-4d45-93e0-6b6355807eac  01/04/2024
# 4             5                            005-003147  12/02/2024
# ..          ...                                   ...         ...
# 195           5  84cd8345-4039-4d84-9805-de945900a88b  23/12/2024
# 196           1                            001-004483  01/08/2024
# 197           5                            005-003258  18/03/2024
# 198           5                            005-001208  29/01/2024
# 199           5  9a31b211-c35f-4c27-b77f-3d2c9f23e32f  08/03/2024
#
#                                 IDArticle  Quantity  SaleAmount   CostAmount  \
# 0    915e1ba0-a1e7-4875-9cff-5cc30e901d80      36.0     2307.96   2476.80000
# 1                             005-ecb0127       1.0       53.00     36.55000
# 2    40f44bd8-44d8-4fc9-b55c-c62d9e53cdfe      10.0      283.40    188.00000
# 3                               005-32615       1.0        0.00      3.00000
# 4    b7c54fc3-469d-423b-ab20-fd3c9f806b0b       0.6      573.60    358.62000
# ..                                    ...       ...         ...          ...
# 195                           005-edi0502       2.0       63.20     31.61916
# 196                            001-199016       1.0    69152.99  69152.99000
# 197                      005-010a104670ne       2.0       84.80     52.00000
# 198                           005-pmc2051       1.0      116.00     80.80000
# 199                    005-010a093650amta     700.0    19635.00  11907.00000
#
#                           IDPaymentMethod  Documento  CODCUSTOMER  \
# 0                                  021-91  24A040006         6150
# 1                                005-87-1  24S120087         3623
# 2                                   021-6  24A080033         7137
# 3                                005-33-1  24A040012         7987
# 4                                005-81-1  24A020057         3147
# ..                                    ...        ...          ...
# 195                               005-1-1  24S120027         7728
# 196  645631ef-9d10-4164-a2c6-42f7ac77734b  24A080004         4483
# 197                               005-5-1  24A030104         3258
# 198                              005-42-1  24S010037         1208
# 199  3583178e-7085-4500-bbdb-8c55cb87c70d  24A030045         7867
#
#                                                Cliente  CODVOUCHERTYPE  \
# 0                                  FORMATO VERDE; S,L,              10
# 1                               MARISCOS DAPORTA; S,L,              10
# 2                    RONAUTICA QUALITY MARINAS; S,L,U,              10
# 3                              FERREIRA & MOXEXO; LDA,              11
# 4                                     MARESMAR; S,L,U,              10
# ..                                                 ...             ...
# 195                           MOLUSCOS ANDALUCIA; S,L,              10
# 196  ORGANIZACION DE PRODUCTORES DE MEJILLON DE GAL...              10
# 197                            MOLUSCOS TRONCOSO; S,L,              10
# 198                         MOLUSCOS RIAS BAIXAS; S,A,              10
# 199                             F & M ECOENVASES; S,L,              10
#
#                   tipoasiento CODPRODUCTLINE  \
# 0           VENTAS NACIONALES          MFR01
# 1           VENTAS NACIONALES            MF8
# 2           VENTAS NACIONALES          MFR04
# 3    VENTAS INTRACOMUNITARIAS            MF1
# 4           VENTAS NACIONALES            MF6
# ..                        ...            ...
# 195         VENTAS NACIONALES            MF8
# 196         VENTAS NACIONALES           MF00
# 197         VENTAS NACIONALES            MF6
# 198         VENTAS NACIONALES            MF8
# 199         VENTAS NACIONALES            MF6
#
#                           macrofamilia CODPRODUCTFAMILY  \
# 0                       Custom Molding            FR01A
# 1                     Maquinaria y SAT              F35
# 2                               Marine            FR04B
# 3                      Consumo Interno               F8
# 4                  Envases y Embalajes              F13
# ..                                 ...              ...
# 195                   Maquinaria y SAT              F35
# 196  Servicios Grupo y AdministraciÃ³n              F00
# 197                Envases y Embalajes              F33
# 198                   Maquinaria y SAT              F35
# 199                Envases y Embalajes              F33
#
#                                familia CODPRODUCTSUBFAMILY  \
# 0                        Formato Verde                 CA2
# 1                      Consumibles SAT                 ECB
# 2                    Nautica Deportiva                 ND2
# 3        Consumo Interno y componentes                  32
# 4                       Envases Madera                 133
# ..                                 ...                 ...
# 195                    Consumibles SAT                  ED
# 196  Servicios Grupo y AdministraciÃ³n                   2
# 197           Sacos y Mallas Extruidas                  10
# 198                    Consumibles SAT                 PMC
# 199           Sacos y Mallas Extruidas                  10
#
#                                  subfamilia
# 0                                CINTURONES
# 1                     REPUESTOS ECONOMY BAG
# 2                   COMPLEMENTOS PANTALANES
# 3         CAJAS-MATERIA PRIMA - COMPONENTES
# 4                    CAIXAS RECTAS CLASICAS
# ..                                      ...
# 195  REPUESTOS EQUIPO DEPURACION Y ESTOCAJE
# 196          OTRAS OPERACIONES (NO NEGOCIO)
# 197                          MALLA MOLUSCOS
# 198        REPUESTOS PESADORAS MULTICABEZAL
# 199                          MALLA MOLUSCOS
#
# [200 rows x 19 columns]

# %% [markdown]
# ## Histogramas

# %%
pip install matplotlib seaborn
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.7-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.60.1-cp313-cp313-win_amd64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\smp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\smp\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\smp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\smp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\smp\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\smp\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\smp\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\smp\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\smp\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.7-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------------------- -------------------- 3.9/8.1 MB 20.8 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 22.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 22.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 22.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 22.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 22.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 22.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 22.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 22.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 22.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 22.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 3.2 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------------------------------- -- 2.1/2.3 MB 25.8 MB/s eta 0:00:01
#    ------------------------------------- -- 2.1/2.3 MB 25.8 MB/s eta 0:00:01
#    ------------------------------------- -- 2.1/2.3 MB 25.8 MB/s eta 0:00:01
#    ------------------------------------- -- 2.1/2.3 MB 25.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 2.2 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl (73 kB)
# Installing collected packages: kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 kiwisolver-1.4.9 matplotlib-3.10.7 seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\smp\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
columnas_num=df.select_dtypes(include=['number']).columns.tolist()

# %%
for col in columnas_num:
    plt.figure()
    sns.histplot(df[col], kde=True)
    plt.show()

# %% [markdown]
# ## Boxplots

# %%
for col in columnas_num:
    plt.figure(figsize=(10, 1))
    sns.boxplot(x=df[col])
    plt.show()
